# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from tqdm import tqdm

# %%
response = requests.get('https://lifehacker.ru/topics/technology/') #https://lifehacker.ru/topics/technology/
response.text
# Out:
# '<!DOCTYPE html><html  lang="ru-RU"><head><meta charset="utf-8">\n<meta name="viewport" content="width=device-width, initial-scale=1">\n<title>Технологии — Лайфхакер</title>\n<link rel="preconnect" href="https://mc.yandex.ru">\n<link rel="preconnect" href="https://static.criteo.net">\n<link rel="preconnect" href="https://exchange.buzzoola.com">\n<link rel="preconnect" href="https://pb.adriver.ru">\n<link rel="preconnect" href="https://ad.mail.ru">\n<script src="https://yandex.ru/ads/system/context.js" crossorigin="anonymous" async></script>\n<script src="https://yandex.ru/ads/system/header-bidding.js" async></script>\n<style>@font-face{ascent-override:92%;descent-override:14%;font-family:Commissioner Fallback;size-adjust:102%;src:local("Trebuchet MS")}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:400;src:url(/_nuxt/commissioner-cyrillic-ext-DkishM3g.woff2) format("woff2");unicode-range:u+0460-052f,u+1c80-1c8a,u+20b4,u+2de0-2dff,u+a640-a69f,u+fe2e-fe2f}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:400;src:url(/_nuxt/commissioner-cyrillic-CXRMZCSJ.woff2) format("woff2");unicode-range:u+0301,u+0400-045f,u+0490-0491,u+04b0-04b1,u+2116}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:400;src:url(/_nuxt/commissioner-latin-ext-DHU98tzF.woff2) format("woff2");unicode-range:u+0100-02ba,u+02bd-02c5,u+02c7-02cc,u+02ce-02d7,u+02dd-02ff,u+0304,u+0308,u+0329,u+1d00-1dbf,u+1e00-1e9f,u+1ef2-1eff,u+2020,u+20a0-20ab,u+20ad-20c0,u+2113,u+2c60-2c7f,u+a720-a7ff}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:400;src:url(/_nuxt/commissioner-latin-BQgS9_UG.woff2) format("woff2");unicode-range:u+00??,u+0131,u+0152-0153,u+02bb-02bc,u+02c6,u+02da,u+02dc,u+0304,u+0308,u+0329,u+2000-206f,u+20ac,u+2122,u+2191,u+2193,u+2212,u+2215,u+feff,u+fffd}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:600;src:url(/_nuxt/commissioner-cyrillic-ext-DkishM3g.woff2) format("woff2");unicode-range:u+0460-052f,u+1c80-1c8a,u+20b4,u+2de0-2dff,u+a640-a69f,u+fe2e-fe2f}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:600;src:url(/_nuxt/commissioner-cyrillic-CXRMZCSJ.woff2) format("woff2");unicode-range:u+0301,u+0400-045f,u+0490-0491,u+04b0-04b1,u+2116}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:600;src:url(/_nuxt/commissioner-latin-ext-DHU98tzF.woff2) format("woff2");unicode-range:u+0100-02ba,u+02bd-02c5,u+02c7-02cc,u+02ce-02d7,u+02dd-02ff,u+0304,u+0308,u+0329,u+1d00-1dbf,u+1e00-1e9f,u+1ef2-1eff,u+2020,u+20a0-20ab,u+20ad-20c0,u+2113,u+2c60-2c7f,u+a720-a7ff}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:600;src:url(/_nuxt/commissioner-latin-BQgS9_UG.woff2) format("woff2");unicode-range:u+00??,u+0131,u+0152-0153,u+02bb-02bc,u+02c6,u+02da,u+02dc,u+0304,u+0308,u+0329,u+2000-206f,u+20ac,u+2122,u+2191,u+2193,u+2212,u+2215,u+feff,u+fffd}@font-face{ascent-override:90%;descent-override:20%;font-family:PT Root Fallback;size-adjust:99%;src:local("Arial")}@font-face{font-display:swap;font-family:PT Root;font-style:normal;font-weight:700;src:url(/_nuxt/pt-root-bold-cyrillic-ext-DvRWtDjP.woff2) format("woff2");unicode-range:u+0460-052f,u+1c80-1c8a,u+20b4,u+2de0-2dff,u+a640-a69f,u+fe2e-fe2f}@font-face{font-display:swap;font-family:PT Root;font-style:normal;font-weight:700;src:url(/_nuxt/pt-root-bold-cyrillic-BLhMUhD6.woff2) format("woff2");unicode-range:u+0301,u+0400-045f,u+0490-0491,u+04b0-04b1,u+2116}@font-face{font-display:swap;font-family:PT Root;font-style:normal;font-weight:700;src:url(/_nuxt/pt-root-bold-latin-ext-CNk3-nEk.woff2) format("woff2");unicode-range:u+0100-02ba,u+02bd-02c5,u+02c7-02cc,u+02ce-02d7,u+02dd-02ff,u+0304,u+0308,u+0329,u+1d00-1dbf,u+1e00-1e9f,u+1ef2-1eff,u+2020,u+20a0-20ab,u+20ad-20c0,u+2113,u+2c60-2c7f,u+a720-a7ff}@font-face{font-display:swap;font-family:PT Root;font-style:nor ...

# %%
base_url = 'https://lifehacker.ru/topics/technology/'
response = requests.get('https://lifehacker.ru/topics/technology/') # получаем контент первой страницы
soup = BeautifulSoup(response.text, 'lxml') # инициализируем объект bs4 и задаем парсер lxml

# %%
soup.find_all('a', class_='lh-small-article-card__link') #ищем все a-элементы с классом lh-small-article-card__link
# Out:
# [<a aria-label="11 новых игр для Android и iOS: лучшее за&amp;nbsp;июль" class="lh-small-article-card__link" data-jest="link" href="/igry-android-ios-iyul-2025/" title="11 новых игр для Android и iOS: лучшее за&amp;nbsp;июль"><!--[--><!--]--></a>,
#  <a aria-label="Вместо «Скрепыша»: Microsoft представила Copilot Appearance — ИИ-помощника с приятным «лицом»" class="lh-small-article-card__link" data-jest="link" href="/anons-copilot-appearance/" title="Вместо «Скрепыша»: Microsoft представила Copilot Appearance — ИИ-помощника с приятным «лицом»"><!--[--><!--]--></a>,
#  <a aria-label="Lenovo выпустила доступный мини-ПК с мощным процессором AMD" class="lh-small-article-card__link" data-jest="link" href="/anons-lenovo-lecoo-mini-pro/" title="Lenovo выпустила доступный мини-ПК с мощным процессором AMD"><!--[--><!--]--></a>,
#  <a aria-label="Как выбрать смарт-часы в 2025 году: пошаговое руководство" class="lh-small-article-card__link" data-jest="link" href="/kak-vybrat-smart-chasy/" title="Как выбрать смарт-часы в 2025 году: пошаговое руководство"><!--[--><!--]--></a>,
#  <a aria-label="Названы устройства Xiaomi, Redmi и Poco, которые не получат HyperOS 3 на базе Android 16" class="lh-small-article-card__link" data-jest="link" href="/podderzhka-redmi-note-12/" title="Названы устройства Xiaomi, Redmi и Poco, которые не получат HyperOS 3 на базе Android 16"><!--[--><!--]--></a>,
#  <a aria-label="Alibaba прокачала линейку ИИ-моделей Qwen3 — особенно в математике и кодинге" class="lh-small-article-card__link" data-jest="link" href="/anons-qwen3/" title="Alibaba прокачала линейку ИИ-моделей Qwen3 — особенно в математике и кодинге"><!--[--><!--]--></a>,
#  <a aria-label="Xiaomi выпустила вертикальный пылесос для влажной и сухой уборки с функцией быстрой сушки&amp;nbsp;пола" class="lh-small-article-card__link" data-jest="link" href="/pylesosy-xiaomi-2025/" title="Xiaomi выпустила вертикальный пылесос для влажной и сухой уборки с функцией быстрой сушки&amp;nbsp;пола"><!--[--><!--]--></a>,
#  <a aria-label="Промпт дня: «помоги выбрать» — чтобы чат-бот предложил оптимальный вариант" class="lh-small-article-card__link" data-jest="link" href="/prompt-dnya-pomogi-vybrat/" title="Промпт дня: «помоги выбрать» — чтобы чат-бот предложил оптимальный вариант"><!--[--><!--]--></a>,
#  <a aria-label="Apple добавила новые возрастные рейтинги в App Store — появились приложения 18+" class="lh-small-article-card__link" data-jest="link" href="/vozrastnye-reitingi-v-app-store/" title="Apple добавила новые возрастные рейтинги в App Store — появились приложения 18+"><!--[--><!--]--></a>,
#  <a aria-label="Honor выпустила Pad X7 — компактный и недорогой планшет с Android 15" class="lh-small-article-card__link" data-jest="link" href="/anons-honor-pad-x7/" title="Honor выпустила Pad X7 — компактный и недорогой планшет с Android 15"><!--[--><!--]--></a>,
#  <a aria-label="Как установить iOS 26 уже сегодня" class="lh-small-article-card__link" data-jest="link" href="/kak-ustanovit-ios-26/" title="Как установить iOS 26 уже сегодня"><!--[--><!--]--></a>,
#  <a aria-label="Обзор Honor Pad 10 — доступного планшета для развлечений и работы на&amp;nbsp;ходу" class="lh-small-article-card__link" data-jest="link" href="/honor-pad-10-obzor/" title="Обзор Honor Pad 10 — доступного планшета для развлечений и работы на&amp;nbsp;ходу"><!--[--><!--]--></a>,
#  <a aria-label="Apple запустила онлайн-конструктор обоев — для смартфонов, планшетов и компьютеров" class="lh-small-article-card__link" data-jest="link" href="/konstruktor-oboev-apple/" title="Apple запустила онлайн-конструктор обоев — для смартфонов, планшетов и компьютеров"><!--[--><!--]--></a>,
#  <a aria-label="Apple выпустила публичные бета-версии iOS 26, macOS Tahoe 26 и других систем с новым дизайном Liquid Glass" class="lh-small-article-card__link" data-jest="link" href="/publichnaya-beta-ios-26/" title="Apple выпустила публичные бета-версии iOS 26, macOS Tahoe 26 и других систем с новым дизайном Liquid Glass"><!--[--><!--]--></a>,
#  <a aria-label="Xiaomi обновила свою крохотную ТВ-приставку Stick 4K — теперь с HDR10+ и Google TV" class="lh-small-article-card__link" data-jest="link" href="/anons-xiaomi-tv-stick-4k-2/" title="Xiaomi обновила свою крохотную ТВ-приставку Stick 4K — теперь с HDR10+ и Google TV"><!--[--><!--]--></a>,
#  <a aria-label="Технолайфхак: как сделать кружочки в Telegram чётче за пару касаний" class="lh-small-article-card__link" data-jest="link" href="/kak-sdelat-kruzhochki-v-telegram-chyotche/" title="Технолайфхак: как сделать кружочки в Telegram чётче за пару касаний"><!--[--><!--]--></a>,
#  <a aria-label="Компьютеры на Windows теперь можно блокировать удалённо с помощью смартфона" class="lh-small-article-card__link" data-jest="link" href="/blokirovka-windows-so-smartfona/" title="Компьютеры на Windows теперь можно блокировать удалённо с помощью смартфона"><!--[--><!--]--></a>,
#  <a aria-label="Xiaomi показала бюджетный набор из беспроводной клавиатуры и бесшумной мыши" class="lh-small-article-card__link" data-jest="link" href="/vypushheny-klaviatura-i-mysh-xiaomi/" title="Xiaomi показала бюджетный набор из беспроводной клавиатуры и бесшумной мыши"><!--[--><!--]--></a>,
#  <a aria-label="Не только Snapdragon Elite 2: инсайдер раскрыл важное нововведение в Galaxy S26&amp;nbsp;Ultra" class="lh-small-article-card__link" data-jest="link" href="/zaryadka-galaxy-s26-ultra/" title="Не только Snapdragon Elite 2: инсайдер раскрыл важное нововведение в Galaxy S26&amp;nbsp;Ultra"><!--[--><!--]--></a>,
#  <a aria-label="Официально: iPhone и некоторые Android-смартфоны получат 25-ваттную зарядку Qi2" class="lh-small-article-card__link" data-jest="link" href="/anons-qi2-25-vt/" title="Официально: iPhone и некоторые Android-смартфоны получат 25-ваттную зарядку Qi2"><!--[--><!--]--></a>,
#  <a aria-label="WhatsApp научится напоминать о сообщениях, на которые нужно ответить" class="lh-small-article-card__link" data-jest="link" href="/whatsapp-nauchitsya-napominat-o-soobshheniyax/" title="WhatsApp научится напоминать о сообщениях, на которые нужно ответить"><!--[--><!--]--></a>,
#  <a aria-label="Google случайно раскрыла все модели Pixel 10 — почти за месяц до презентации" class="lh-small-article-card__link" data-jest="link" href="/utechka-lineiki-pixel-10/" title="Google случайно раскрыла все модели Pixel 10 — почти за месяц до презентации"><!--[--><!--]--></a>,
#  <a aria-label="Энтузиаст выпустил чехол для iPhone, который превращает Lightning-разъём в USB‑C" class="lh-small-article-card__link" data-jest="link" href="/chexol-iphone-usb-c/" title="Энтузиаст выпустил чехол для iPhone, который превращает Lightning-разъём в USB‑C"><!--[--><!--]--></a>,
#  <a aria-label="В Китае протестировали 6G — технология передаёт 50 ГБ за 1,4 секунды" class="lh-small-article-card__link" data-jest="link" href="/v-kitae-protestirovali-6g/" title="В Китае протестировали 6G — технология передаёт 50 ГБ за 1,4 секунды"><!--[--><!--]--></a>,
#  <a aria-label="VSCO выпустила Capture — бесплатное приложение-камеру для iPhone с плёночными фильтрами" class="lh-small-article-card__link" data-jest="link" href="/anons-vsco-capture/" title="VSCO выпустила Capture — бесплатное приложение-камеру для iPhone с плёночными фильтрами"><!--[--><!--]--></a>,
#  <a aria-label="Apple снова переобулась: в iOS 26 вернули «жидкое стекло»" class="lh-small-article-card__link" data-jest="link" href="/vyshla-chetvertaya-beta-ios-26/" title="Apple снова переобулась: в iOS 26 вернули «жидкое стекло»"><!--[--><!--]--></a>,
#  <a aria-label="15 настроек Windows 11, которые сделают её в разы удобнее" class="lh-small-article-card__link" data-jest="link" href="/nastroiki-windows-11/" title="15 настроек Windows 11, которые сделают её в разы удобнее"><!--[--><!--]--></a>,
#  <a aria-label="Глава OpenAI Сэм Альтман назвал три худших сценария развития ИИ" class="lh-small-article-card__link" data-jest="link" href="/xudshie-scenarii-s-ii/" title="Глава OpenAI Сэм Альтман назвал три худших сценария развития ИИ"><!--[--><!--]--></a>,
#  <a aria-label="В Apple Watch может наконец-то появиться функция оценки сна" class="lh-small-article-card__link" data-jest="link" href="/ocenka-sna-v-apple-watch/" title="В Apple Watch может наконец-то появиться функция оценки сна"><!--[--><!--]--></a>,
#  <a aria-label="Motorola возродит культовую серию умных часов Moto 360 — появились рендеры" class="lh-small-article-card__link" data-jest="link" href="/rendery-moto-360-2025/" title="Motorola возродит культовую серию умных часов Moto 360 — появились рендеры"><!--[--><!--]--></a>]

# %%
from types import CellType
raw_items = soup.find_all('a', class_='lh-small-article-card__link')  # ищем все a-элементы с классом lh-small-article-card__link
links = [item.get('href').replace('/#comments', '') for item in raw_items] # получаем у ссылок только href-атрибут, убираем подстроку '/comments'
links
# Out:
# ['/igry-android-ios-iyul-2025/',
#  '/anons-copilot-appearance/',
#  '/anons-lenovo-lecoo-mini-pro/',
#  '/kak-vybrat-smart-chasy/',
#  '/podderzhka-redmi-note-12/',
#  '/anons-qwen3/',
#  '/pylesosy-xiaomi-2025/',
#  '/prompt-dnya-pomogi-vybrat/',
#  '/vozrastnye-reitingi-v-app-store/',
#  '/anons-honor-pad-x7/',
#  '/kak-ustanovit-ios-26/',
#  '/honor-pad-10-obzor/',
#  '/konstruktor-oboev-apple/',
#  '/publichnaya-beta-ios-26/',
#  '/anons-xiaomi-tv-stick-4k-2/',
#  '/kak-sdelat-kruzhochki-v-telegram-chyotche/',
#  '/blokirovka-windows-so-smartfona/',
#  '/vypushheny-klaviatura-i-mysh-xiaomi/',
#  '/zaryadka-galaxy-s26-ultra/',
#  '/anons-qi2-25-vt/',
#  '/whatsapp-nauchitsya-napominat-o-soobshheniyax/',
#  '/utechka-lineiki-pixel-10/',
#  '/chexol-iphone-usb-c/',
#  '/v-kitae-protestirovali-6g/',
#  '/anons-vsco-capture/',
#  '/vyshla-chetvertaya-beta-ios-26/',
#  '/nastroiki-windows-11/',
#  '/xudshie-scenarii-s-ii/',
#  '/ocenka-sna-v-apple-watch/',
#  '/rendery-moto-360-2025/']

# %%
import requests
requests.get('https://lifehacker.ru/topics/technology/').text
# Out:
# '<!DOCTYPE html><html  lang="ru-RU"><head><meta charset="utf-8">\n<meta name="viewport" content="width=device-width, initial-scale=1">\n<title>Технологии — Лайфхакер</title>\n<link rel="preconnect" href="https://mc.yandex.ru">\n<link rel="preconnect" href="https://static.criteo.net">\n<link rel="preconnect" href="https://exchange.buzzoola.com">\n<link rel="preconnect" href="https://pb.adriver.ru">\n<link rel="preconnect" href="https://ad.mail.ru">\n<script src="https://yandex.ru/ads/system/context.js" crossorigin="anonymous" async></script>\n<script src="https://yandex.ru/ads/system/header-bidding.js" async></script>\n<style>@font-face{ascent-override:92%;descent-override:14%;font-family:Commissioner Fallback;size-adjust:102%;src:local("Trebuchet MS")}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:400;src:url(/_nuxt/commissioner-cyrillic-ext-DkishM3g.woff2) format("woff2");unicode-range:u+0460-052f,u+1c80-1c8a,u+20b4,u+2de0-2dff,u+a640-a69f,u+fe2e-fe2f}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:400;src:url(/_nuxt/commissioner-cyrillic-CXRMZCSJ.woff2) format("woff2");unicode-range:u+0301,u+0400-045f,u+0490-0491,u+04b0-04b1,u+2116}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:400;src:url(/_nuxt/commissioner-latin-ext-DHU98tzF.woff2) format("woff2");unicode-range:u+0100-02ba,u+02bd-02c5,u+02c7-02cc,u+02ce-02d7,u+02dd-02ff,u+0304,u+0308,u+0329,u+1d00-1dbf,u+1e00-1e9f,u+1ef2-1eff,u+2020,u+20a0-20ab,u+20ad-20c0,u+2113,u+2c60-2c7f,u+a720-a7ff}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:400;src:url(/_nuxt/commissioner-latin-BQgS9_UG.woff2) format("woff2");unicode-range:u+00??,u+0131,u+0152-0153,u+02bb-02bc,u+02c6,u+02da,u+02dc,u+0304,u+0308,u+0329,u+2000-206f,u+20ac,u+2122,u+2191,u+2193,u+2212,u+2215,u+feff,u+fffd}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:600;src:url(/_nuxt/commissioner-cyrillic-ext-DkishM3g.woff2) format("woff2");unicode-range:u+0460-052f,u+1c80-1c8a,u+20b4,u+2de0-2dff,u+a640-a69f,u+fe2e-fe2f}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:600;src:url(/_nuxt/commissioner-cyrillic-CXRMZCSJ.woff2) format("woff2");unicode-range:u+0301,u+0400-045f,u+0490-0491,u+04b0-04b1,u+2116}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:600;src:url(/_nuxt/commissioner-latin-ext-DHU98tzF.woff2) format("woff2");unicode-range:u+0100-02ba,u+02bd-02c5,u+02c7-02cc,u+02ce-02d7,u+02dd-02ff,u+0304,u+0308,u+0329,u+1d00-1dbf,u+1e00-1e9f,u+1ef2-1eff,u+2020,u+20a0-20ab,u+20ad-20c0,u+2113,u+2c60-2c7f,u+a720-a7ff}@font-face{font-display:swap;font-family:Commissioner;font-style:normal;font-weight:600;src:url(/_nuxt/commissioner-latin-BQgS9_UG.woff2) format("woff2");unicode-range:u+00??,u+0131,u+0152-0153,u+02bb-02bc,u+02c6,u+02da,u+02dc,u+0304,u+0308,u+0329,u+2000-206f,u+20ac,u+2122,u+2191,u+2193,u+2212,u+2215,u+feff,u+fffd}@font-face{ascent-override:90%;descent-override:20%;font-family:PT Root Fallback;size-adjust:99%;src:local("Arial")}@font-face{font-display:swap;font-family:PT Root;font-style:normal;font-weight:700;src:url(/_nuxt/pt-root-bold-cyrillic-ext-DvRWtDjP.woff2) format("woff2");unicode-range:u+0460-052f,u+1c80-1c8a,u+20b4,u+2de0-2dff,u+a640-a69f,u+fe2e-fe2f}@font-face{font-display:swap;font-family:PT Root;font-style:normal;font-weight:700;src:url(/_nuxt/pt-root-bold-cyrillic-BLhMUhD6.woff2) format("woff2");unicode-range:u+0301,u+0400-045f,u+0490-0491,u+04b0-04b1,u+2116}@font-face{font-display:swap;font-family:PT Root;font-style:normal;font-weight:700;src:url(/_nuxt/pt-root-bold-latin-ext-CNk3-nEk.woff2) format("woff2");unicode-range:u+0100-02ba,u+02bd-02c5,u+02c7-02cc,u+02ce-02d7,u+02dd-02ff,u+0304,u+0308,u+0329,u+1d00-1dbf,u+1e00-1e9f,u+1ef2-1eff,u+2020,u+20a0-20ab,u+20ad-20c0,u+2113,u+2c60-2c7f,u+a720-a7ff}@font-face{font-display:swap;font-family:PT Root;font-style:nor ...

# %%
parsed_urls = []

# %%
for page_num in range(1, 11):
    url = f'{base_url}/?page={page_num}' # подставляем нужный номер страницы для пагинации, дальше парсим каждую страницу аналогично коду выше
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'lxml')
    raw_items = soup.find_all('a', class_='lh-article-card-controls__comments')
    parsed_urls += [item.get('href').replace('/#comments', '') for item in raw_items]

# %%
len(parsed_urls)
# Out:
# 300

# %%
parsed_urls[35:45]
# Out:
# ['/anons-qwen3',
#  '/pylesosy-xiaomi-2025',
#  '/prompt-dnya-pomogi-vybrat',
#  '/vozrastnye-reitingi-v-app-store',
#  '/anons-honor-pad-x7',
#  '/kak-ustanovit-ios-26',
#  '/honor-pad-10-obzor',
#  '/konstruktor-oboev-apple',
#  '/publichnaya-beta-ios-26',
#  '/anons-xiaomi-tv-stick-4k-2']

# %%
base_url = 'https://lifehacker.ru/'

# %%
response = requests.get('https://lifehacker.ru/anons-copilot-appearance/')
soup = BeautifulSoup(response.text, 'lxml')
soup.find('article', class_='single-article__post-content single-article__content-container').text
# Out:
# 'Microsoft продолжает активно развивать Copilot, стремясь сделать его полноценным персональным помощником на основе искусственного интеллекта. В прошлом году компания внедрила разговорный голосовой режим, а теперь представила функцию Copilot Appearance — виртуального персонажа, способного взаимодействовать с пользователями в режиме реального времени.Со временем у Copilot появится пространство, которое он сможет назвать своим домом, и он будет демонстрировать признаки «старения». Мне очень интересна эта идея цифровой патины. Вещи, которые я люблю в своём мире, — они немного изношены и имеют потёртости. К сожалению, в цифровом мире у нас нет ощущения возраста.Мустафа СулейманГенеральный директор Microsoft AIПодробностей пока мало. Судя по опубликованным корпорацией изображениям, это «лицо» Copilot, появляющееся во время голосового общения с ним, чтобы не было ощущения разговора с пустотой.Изображение: MicrosoftCopilot Appearance — это эксперимент, предлагающий новый визуальный способ взаимодействия с ИИ, основанный на реалистичных выражениях и голосе, подчёркивают в Microsoft. Для него была разработана дружелюбная и располагающая мимика: виртуальный помощник может улыбаться, кивать и даже выражать удивление, если это соответствует контексту беседы.Изображение: MicrosoftОн уже доступен в тестовом режиме для избранных пользователей из США, Великобритании и Канады. Сроки запуска для всех пока не называются.Читайте также🚀Lenovo выпустила доступный мини-ПК с мощным процессором AMDНазваны устройства Xiaomi, Redmi и Poco, которые не получат HyperOS 3 на базе Android 16Alibaba прокачала линейку ИИ-моделей Qwen3 — особенно в математике и кодинге'

# %%
soup.find('h1', class_='article-card__title').text
# Out:
# 'Вместо «Скрепыша»: Microsoft представила Copilot Appearance — ИИ-помощника с приятным «лицом»'

# %%
result = []

for url in tqdm(parsed_urls):
    article = {}

    article_url = f'{base_url}{url}' # подставляем часть ссылки на материал
    response = requests.get(article_url)
    soup = BeautifulSoup(response.text, 'lxml')

    article['title'] = soup.find('h1', class_='article-card__title').text # Получаем текст из span в первом h1 с классом tm-title_h1
    article['text'] = soup.find('article', class_='single-article__post-content single-article__content-container').text # Получаем весь текст из div с классом tm-article-body
    votes_element = soup.find('span', class_='reactioncurrent-count')
    article['votes_count'] = votes_element.text.strip() if votes_element else 0


    result.append(article)
# Out:
# 100%|██████████| 300/300 [12:40<00:00,  2.53s/it]

# %%
pd.set_option('display.max_colwidth', 400)

# %%
data = pd.DataFrame(result)
data.head()
# Out:
#                                                                                            title  \
# 0                                                 11 новых игр для Android и iOS: лучшее за июль
# 1  Вместо «Скрепыша»: Microsoft представила Copilot Appearance — ИИ-помощника с приятным «лицом»
# 2                                    Lenovo выпустила доступный мини-ПК с мощным процессором AMD
# 3                                      Как выбрать смарт-часы в 2025 году: пошаговое руководство
# 4       Названы устройства Xiaomi, Redmi и Poco, которые не получат HyperOS 3 на базе Android 16
#
#                                                                                                                                                                                                                                                                                                                                                                                                               text  \
# 0  Продолжаем дайджест мобильных игр, вышедших за месяц. Прошлая подборка выдалась богатой на достойные находки, но и новый выпуск тоже не подкачал. Уверены, каждый найдёт что-нибудь интересное для себя.1. Red Bull PlaygroundsДрайвовая аркада для фанатов экстремального спорта, где паркур, BMX и скейтбординг сливаются в одно целое. В Red Bull Playgrounds можно строить собственные трассы, выделыват...
# 1  Microsoft продолжает активно развивать Copilot, стремясь сделать его полноценным персональным помощником на основе искусственного интеллекта. В прошлом году компания внедрила разговорный голосовой режим, а теперь представила функцию Copilot Appearance — виртуального персонажа, способного взаимодействовать с пользователями в режиме реального времени.Со временем у Copilot появится пространство, ...
# 2  Lenovo выпустила в Китае новый мини-ПК Lecoo Mini Pro, оснащённый процессором AMD Ryzen 7 8745H. Этот чипсет относится к линейке Hawk Point и представляет собой китайскую версию Ryzen 7 8745HS.Устройство также оснащён графическим процессором Radeon 780M iGPU, который обеспечивает возможность запуска большинства современных игр AAA с низкими и средними настройками графики. Оно поддерживает до 3...
# 3  ОглавлениеРазберитесь, какие виды смарт‑часов бываютВыберите тип циферблатаОпределитесь с дизайномВыберите материал корпусаПодберите необходимый размер корпусаУточните тип дисплея и его характеристикиИзучите поддерживаемые функцииОцените производительность и памятьПроверьте возможности связи и беспроводные интерфейсыИзучите доступные сенсоры и датчикиОпределитесь с операционной системойПроверь...
# 4  Xiaomi назвала устройства, которые останутся без HyperOS 3 на базе Android 16. Некоторые модели из списка до сих пор пользуются большой популярностью, что может вызвать вопросы у пользователей бренда.Решение прекратить их поддержку связано с аппаратными ограничениями. Они не потянут новые функции, включая анимацию интерфейса «жидкого стекла» и улучшения на основе искусственного интеллекта, кот...
#
#    votes_count
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
